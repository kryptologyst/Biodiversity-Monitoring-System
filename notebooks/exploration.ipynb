# %% [markdown]
# # Biodiversity Monitoring System - Data Exploration
#
# This notebook provides an interactive exploration of the biodiversity monitoring system data and models.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from omegaconf import OmegaConf
import sys
from pathlib import Path

# Add src to path
sys.path.append(str(Path.cwd() / "src"))

from data.processing import BiodiversityDataGenerator, DataProcessor
from models.biodiversity_models import ModelTrainer, BaselineModels
from eval.evaluation import BiodiversityEvaluator

# Set style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
